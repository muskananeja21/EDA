# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"C:\Users\Muskan Aneja\OneDrive\Desktop\movie.csv")
data.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
data.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#              Director              Star1              Star2           Star3  \
# 995     Blake Edwards     Audrey Hepburn     George Peppard   Patricia Neal
# 996    George Stevens   Elizabeth Taylor        Rock Hudson      James Dean
# 997    Fred Zinnemann     Burt Lancaster   Montgomery Clift    Deborah Kerr
# 998  Alfred Hitchcock  Tallulah Bankhead        John Hodiak   Walter Slezak
# 999  Alfred Hitchcock       Robert Donat  Madeleine Carroll  Lucie Mannheim
#
#               Star4  No_of_Votes       Gross
# 995     Buddy Ebsen       166544         NaN
# 996   Carroll Baker        34075         NaN
# 997      Donna Reed        43374  30,500,000
# 998  William Bendix        26471         NaN
# 999  Godfrey Tearle        51853         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
print("The shape of the dataset is: {} rows and {} columns".format(data.shape[0], data.shape[1]))
# Out:
# The shape of the dataset is: 1000 rows and 16 columns

# %%
data.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
data = data.rename(columns={"Series_Title": "Movies_Title"})

# %%
data = data.drop('Overview', axis=1)

# %%
data.head(3)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Movies_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# 0     Tim Robbins  Morgan Freeman     Bob Gunton  William Sadler      2343110
# 1   Marlon Brando       Al Pacino     James Caan    Diane Keaton      1620367
# 2  Christian Bale    Heath Ledger  Aaron Eckhart   Michael Caine      2303232
#
#          Gross
# 0   28,341,469
# 1  134,966,411
# 2  534,858,444

# %%
print(data['Gross'].head(1))
data['Gross'] = data['Gross'].str.replace(',', '')
print(data['Gross'].head(1))

data['Gross'] = data['Gross'].astype('float64')
data['Gross'] = data['Gross'].replace(np.nan, 0)
# Out:
# 0    28,341,469
# Name: Gross, dtype: object
# 0    28341469
# Name: Gross, dtype: object

# %%
data['Gross'] = data['Gross'].astype(int)

# %%
data['Gross'].dtype
# Out:
# dtype('int32')

# %%
columns = ['IMDB_Rating', 'No_of_Votes', 'Meta_score', 'Gross']

# %%
correlation_matrix = data[columns].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
numerical_attributes = ['IMDB_Rating', 'Meta_score', 'No_of_Votes', 'Gross']
data[numerical_attributes].hist(figsize = (18, 9), color = 'pink', edgecolor = 'black', layout = (2, 2));

# %%
data.describe(include = ['O'])
# Out:
#                                               Poster_Link Movies_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...     Drishyam
# freq                                                    1            2
#
#        Released_Year Certificate  Runtime  Genre          Director      Star1  \
# count           1000         899     1000   1000              1000       1000
# unique           100          16      140    202               548        660
# top             2014           U  100 min  Drama  Alfred Hitchcock  Tom Hanks
# freq              32         234       23     85                14         12
#
#               Star2         Star3          Star4
# count          1000          1000           1000
# unique          841           891            939
# top     Emma Watson  Rupert Grint  Michael Caine
# freq              7             5              4

# %%
top_voted = data.sort_values(['No_of_Votes'], ascending = False)

# %%
plt.figure(figsize=(5, 5))
colors = ['violet', 'pink', 'blue', 'green', 'orange']
g = sns.barplot(x=top_voted['Movies_Title'][:5], y=top_voted['No_of_Votes'][:5], palette=colors)
g.set_title("Top Voted Movies", weight="bold")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 5))
colors = ['violet', 'orange', 'limegreen', 'red', 'skyblue']
g = sns.barplot(x=top_voted['Movies_Title'][:5], y=top_voted['IMDB_Rating'][:5], palette=colors)
g.set_title("IMDB Rating of top voted movies", weight="bold")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data['Gross'].head(5)
# Out:
# 0     28341469
# 1    134966411
# 2    534858444
# 3     57300000
# 4      4360000
# Name: Gross, dtype: int32

# %%
data.loc[data['Gross']==0]
# Out:
#                                            Poster_Link  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 30   https://m.media-amazon.com/images/M/MV5BYjBmYT...
# 32   https://m.media-amazon.com/images/M/MV5BZjc4ND...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# ..                                                 ...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Movies_Title Released_Year Certificate  Runtime  \
# 18                 Hamilton          2020       PG-13  160 min
# 20          Soorarai Pottru          2020           U  153 min
# 30                  Seppuku          1962         NaN  133 min
# 32    It's a Wonderful Life          1946          PG  130 min
# 46           Hotaru no haka          1988           U   89 min
# ..                      ...           ...         ...      ...
# 993                  Blowup          1966           A  111 min
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                          Genre  IMDB_Rating  Meta_score  \
# 18   Biography, Drama, History          8.6        90.0
# 20                       Drama          8.6         NaN
# 30      Action, Drama, Mystery          8.6        85.0
# 32      Drama, Family, Fantasy          8.6        89.0
# 46       Animation, Drama, War          8.5        94.0
# ..                         ...          ...         ...
# 993   Drama, Mystery, Thriller          7.6        82.0
# 995     Comedy, Drama, Romance          7.6        76.0
# 996             Drama, Western          7.6        84.0
# 998                 Drama, War          7.6        78.0
# 999   Crime, Mystery, Thriller          7.6        93.0
#
#                    Director               Star1              Star2  \
# 18              Thomas Kail  Lin-Manuel Miranda       Phillipa Soo
# 20            Sudha Kongara              Suriya           Madhavan
# 30         Masaki Kobayashi     Tatsuya Nakadai     Akira Ishihama
# 32              Frank Capra       James Stewart         Donna Reed
# 46            Isao Takahata     Tsutomu Tatsumi    Ayano Shiraishi
# ..                      ...                 ...                ...
# 993  Michelangelo Antonioni      David Hemmings   Vanessa Redgrave
# 995           Blake Edwards      Audrey Hepburn     George Peppard
# 996          George Stevens    Elizabeth Taylor        Rock Hudson
# 998        Alfred Hitchcock   Tallulah Bankhead        John Hodiak
# 999        Alfred Hitchcock        Robert Donat  Madeleine Carroll
#
#                 Star3                   Star4  No_of_Votes  Gross
# 18    Leslie Odom Jr.  Renée Elise Goldsberry        55291      0
# 20       Paresh Rawal       Aparna Balamurali        54995      0
# 30     Shima Iwashita           Tetsurô Tanba        42004      0
# 32   Lionel Barrymore         Thomas Mitchell       405801      0
# 46    Akemi Yamaguchi       Yoshiko Shinohara       235231      0
# ..                ...                     ...          ...    ...
# 993       Sarah Miles             John Castle        56513      0
# 995     Patricia Neal             Buddy Ebsen       166544      0
# 996        James Dean           Carroll Baker        34075      0
# 998     Walter Slezak          William Bendix        26471      0
# 999    Lucie Mannheim          Godfrey Tearle        51853      0
#
# [169 rows x 15 columns]

# %%
fig,axs=plt.subplots(figsize=(5,5))
colors = ['darkblue', 'darkorange', 'limegreen', 'red', 'skyblue']
g=sns.barplot(x=top_voted['Movies_Title'][:5],y=top_voted['Gross'][:5], palette=colors)
g.set_title("Gross by top rated movies", weight = "bold")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
highest_earning = data.sort_values(['Gross'], ascending = False)
fig,axs=plt.subplots(figsize=(5,5))
colors = ['violet', 'orange', 'limegreen', 'red', 'skyblue']
g=sns.barplot(x=highest_earning['Movies_Title'][:5],y=highest_earning['Gross'][:5], palette = colors)
g.set_title("Movies with highest Gross", weight = "bold")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=data['Released_Year'].value_counts()[:10].index,y=data['Released_Year'].value_counts()[:10])
g.set_title("Maximum Movies released in-", weight = "bold")
g.set_xlabel("Years")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.lineplot(x=data['Director'].value_counts()[:10].index,y=data['Released_Year'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("Directors", weight = "bold")

plt.show()

# %%
import re
duration=[]
for x in data["Runtime"]:
    p=re.compile('\d+')
    j=p.findall(x)
    if len(j)==2:
        duration.append(int(j[1])-int(j[0])+1)
    else:
        duration.append(int(j[0])+1)
data['duration']=duration

# %%
data['duration'].head()
# Out:
# 0    143
# 1    176
# 2    153
# 3    203
# 4     97
# Name: duration, dtype: int64

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.kdeplot(data['duration'])
g.set_title("Time Duration of movies", weight = "bold")
# Out:
# Text(0.5, 1.0, 'Time Duration of movies')

# %%
stars=['Star1','Star2','Star3','Star4']
fig,axs=plt.subplots(4,1,figsize=(20,7))
ax=0
for x in stars:
    axs[ax].bar(data[x].value_counts()[:10].index,data[x].value_counts()[:10])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %%
data['Certificate'].isnull().sum()
# Out:
# 101

# %%
data['Certificate']=data['Certificate'].fillna('Not Rated')

certificates=data[data['Certificate']!='Not Rated']['Certificate']
fig,axs=plt.subplots(figsize=(20,5))
g=sns.countplot(certificates)
g.set_title("Count of Certificates provided", weight = "bold")
plt.show()
# Out:
# C:\Users\Muskan Aneja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.distplot(data['IMDB_Rating'],bins=30)
g.set_title("Distribution of Ratings", weight = "bold")
plt.show()
# Out:
# C:\Users\Muskan Aneja\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from collections import Counter
genre=[]
for x in data['Genre']:
    for y in x.split(','):
        genre.append(y.strip().lower())

count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(y,x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()
# Out:
# C:\Users\Muskan Aneja\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
